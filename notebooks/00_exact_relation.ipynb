# %% [markdown]
# # Exact golden-ratio cosmology relation
# This notebook verifies the idealized analytic prediction without observational fitting.

# %%
from golden_ratio_cosmology.core import ideal_flat_lcdm_prediction
ideal_flat_lcdm_prediction()

# %% [markdown]
# The result applies to flat matter + $\Lambda$ with radiation neglected in the analytic derivation. The project tests radiation and other extensions numerically.
